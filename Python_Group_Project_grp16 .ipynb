# %% [markdown]
# ---
#
# # <span style="color:blue;">🌍 **Project Report on Imports and Exports Data Analysis** 📊</span>
#
# ---

# %% [markdown]
# ---
#
# # **Project Information**
#
# ---
#
# ### **Project Title:**
# **Comprehensive Data Analysis of Imports and Exports Dataset**
#
# ---
#
# ### **Student Details:**
# - **Muskan Bohra**
#   Enrollment Number: **055025**
# - **Rohan Jha**
#   Enrollment Number: **055057**
#
# ---
#
# ### **Project Overview:**
# This project provides a comprehensive analysis of international trade transactions, specifically focusing on both **imports** and **exports**. It includes a detailed dataset that captures numerous attributes related to these transactions. The analysis is designed to offer valuable insights for:
# - **Business Analytics**
# - **Economic Research**
# - **Financial Modeling**
#
# By exploring the intricate details of international trade, this project delivers a broad perspective on trade activities and their economic implications.
#
# ---

# %% [markdown]
# ---
#
# # **Description of Data**
#
# ---
#
# ### **1. Data Source & Size:**
# - **Source:** The dataset for this project was obtained from Kaggle. You can access it via this [Link to Dataset](https://www.kaggle.com/datasets/chakilamvishwas/imports-exports-15000).
# - **Size:** 15,000 records with 16 variables (2.69 MB)
#
# ---
#
# ### **2. Data Type:**
# This is a **cross-sectional dataset**, capturing transactional data at a specific point in time.
#
# ---
#
# ### **3. Data Dimensions:**
# - **Number of Variables:** 16
# - **Number of Observations:** 15,000
#
# ---
#
# ### **4. Data Variable Type:**
#
# #### **Text Variables:**
# - `Transaction_ID`
# - `Country`
# - `Product`
# - `Import_Export`
# - `Date`
# - `Category`
# - `Port`
# - `Shipping_Method`
# - `Supplier`
# - `Customer`
# - `Payment_Terms`
#
# #### **Number Variables:**
# - **Integer:**
#   - `Quantity`
#   - `Customs_Code`
#   - `Invoice_Number`
# - **Decimal:**
#   - `Value`
#   - `Weight`
#
# ---
#
# ### **5. Data Variable Category**
# Identifying **Categorical (Nominal & Ordinal)** and **Non-Categorical** data:
#
# ---
#
# #### **Categorical Data:**
# - **Nominal:**
#   - **Country**
#   - **Product**
#   - **Import Export**
#   - **Category**
#   - **Port**
#   - **Shipping Method**
#   - **Supplier**
#   - **Customer**
#   - **Payment Terms**
#
# ---
#
# #### **Non-Categorical Data:**
# - **Non-Categorical:**
#   - **Quantity**
#   - **Value**
#   - **Customs Code**
#   - **Weight**
#
# ---
#
# | **Sr. No.** | **Data Variable**     | **Category**                          |
# | ----------- | --------------------- | ------------------------------------- |
# | 1.          | Transaction ID        | Index (used for identifying each transaction) |
# | 2.          | Country               | Categorical {Nominal}                 |
# | 3.          | Product               | Categorical {Nominal}                 |
# | 4.          | Import Export         | Categorical {Nominal}                 |
# | 5.          | Quantity              | Non-Categorical                       |
# | 6.          | Value                 | Non-Categorical                       |
# | 7.          | Category              | Categorical {Nominal}                 |
# | 8.          | Port                  | Categorical {Nominal}                 |
# | 9.          | Customs Code          | Non-Categorical                       |
# | 10.         | Weight                | Non-Categorical                       |
# | 11.         | Shipping Method       | Categorical {Nominal}                 |
# | 12.         | Supplier              | Categorical {Nominal}                 |
# | 13.         | Customer              | Categorical {Nominal}                 |
# | 14.         | Invoice Number        | Index (used for identifying each transaction) |
# | 15.         | Payment Terms           | Categorical {Nominal}                 |
#
# ---

# %% [markdown]
# ---
#
# # **Project Objectives & Problem Statements**
#
# ---
#
# ## **Project Objectives:**
#
# 1. **Identify key trends** in import and export activities across different countries and product categories.
# 2. **Understand the distribution** of transaction values and quantities across various categories.
# 3. **Analyze the most frequently used** shipping methods and their relationship to transaction value and weight.
# 4. **Find the minimum and maximum** value of each variable.
# 5. **Calculate the average order value** and quantity per country.
# 6. **Determine the maximum weight** in KGs by shipping method and category.
# 7. **Count products by their payment terms** per category.
# 8. **Rank categories** by the total economic impact (value), with higher values receiving higher ranks.
#
# ---
#
# ## **Problem Statements:**
#
# 1. **How do different countries vary** in terms of the volume and value of imports and exports?
# 2. **Are there specific product categories** that dominate in terms of trade volume and value?
# 3. **What are the most commonly used shipping methods** for high-value transactions?
# 4. **Identify the range of values** and outliers in the dataset.
# 5. **Compare different countries** in terms of purchasing behavior to help tailor marketing strategies or identify high-value markets.
# 6. **Assess which shipping methods** are handling heavier products and which categories have the largest or heaviest products.
# 7. **Provide insights into preferred payment terms** by category to optimize payment options for different product lines.
# 8. **Rank product categories** based on their total economic impact, with categories having the highest impact given the highest rank.
#
# ---

# %% [markdown]
# ---
#
# # **Analysis:**
#
# ---
#
# ### **1. Positive Linear Relationship**
# - **Insight:** The positive coefficient for the linear term suggests that, in general:
#   - **Higher Quantities = Higher Values**
#   - This aligns with intuition: larger quantities often correspond to larger transaction values.
#
# ---
#
# ### **2. Diminishing Returns**
# - **Observation:** The negative quadratic term indicates a diminishing return effect:
#   - As quantity increases further, the **rate of increase in value slows down**.
#   - **Possible Explanations:**
#     - **Bulk Discounts:** Larger purchases might lead to reduced prices.
#     - **Diminishing Marginal Returns:** Additional quantities may not add equivalent value.
#
# ---
#
# ### **3. Model Fit**
# - **Evaluation:** The coefficients indicate a polynomial relationship fitting the data from the top 5 countries. However:
#   - **Further Evaluation Needed:**
#     - Assess model goodness-of-fit using metrics such as:
#       - **R-squared value**
#       - **Residual analysis**
#   - **Goal:** Ensure the model adequately captures the relationship between quantity and value.
#
# ---
#
# ### **Next Steps:**
# - **Conduct Residual Analysis:** Check for patterns in residuals to assess model accuracy.
# - **Calculate R-squared Value:** Determine the proportion of variance explained by the model.
# - **Explore Potential Improvements:** Consider additional variables or interactions that may enhance model performance.
#
# ---

# %% [markdown]
# ---
#
# # **Observations & Findings**
#
# ---
#
# ## **1. Import/Export Trends**
# - Significant variation was observed across countries regarding both **volume** and **value** of imports and exports:
#   - Some countries focus more on **exports** while others have higher **import** activities.
#   - This variation potentially highlights **trade imbalances** or specialization in certain industries.
#
# ---
#
# ## **2. Dominant Product Categories**
# - Certain product categories exhibited a high volume and value of transactions, potentially driving the bulk of trade in the dataset.
#
# ---
#
# ## **3. Minimum and Maximum Variables**
#
# ### **Minimum Transaction:**
# - **Country:** Afghanistan
# - **Product:** American
# - **Import/Export:** Export
# - **Category:** Clothing
# - **Port:** Aaronborough
# - **Shipping Method:** Air
# - **Supplier:** Abbott LLC
# - **Customer:** Aaron Barnes
# - **Payment Terms:** Cash on Delivery
#
# ### **Maximum Transaction:**
# - **Country:** Zimbabwe
# - **Product:** Yourself
# - **Import/Export:** Import
# - **Category:** Toys
# - **Port:** Zacharyland
# - **Shipping Method:** Sea
# - **Supplier:** Zimmerman Ltd
# - **Customer:** Zoe Martin
# - **Payment Terms:** Prepaid
#
# ---
#
# ## **4. Shipping Methods**
# - The most frequently used shipping methods were identified:
#   - **High-value transactions** often utilized faster and more secure shipping options.
#   - **Lower-value transactions** relied on slower, cost-effective methods.
#
# ---
#
# ## **5. Average Order Value and Quantity per Country**
# - **The Solomon Islands:** Highest average transaction value and quantity among the top 5 countries, indicating high-value and large-quantity goods in transactions.
# - **Antarctica:** Second-highest average transaction value; high quantity likely due to bulk imports or exports.
# - **Norway:** High average value with lower quantity, suggesting engagement in high-value goods requiring less volume (e.g., electronics).
# - **Sri Lanka:** High average transaction value with lower quantity, indicating trade in niche, high-value goods.
# - **Puerto Rico:** Balanced trade, where both value and volume are significant.
#
# ---
#
# ## **6. Maximum Weight in KGs by Shipping Method and Category**
# - **Clothing:** Maximum weight consistently around **4900-4990 kgs** across shipping methods.
# - **Electronics:** Similar maximum weight range of **4900-4990 kgs** across methods.
# - **Furniture:** Slight variation, highest maximum weight for land shipping at **4914.57 kgs**, while air and sea shipping around **4965-4990 kgs**.
# - **Machinery:** Highest maximum weight for air shipping at **4994.36 kgs**, while land and sea are around **4900-4990 kgs**.
# - **Toys:** Consistent maximum weight of **4900-4990 kgs** across all shipping methods.
#
# ---
#
# ## **7. Count of Products by Payment Terms per Category**
# - **Payment Term Distribution:**
#   - Across all categories, **Cash on Delivery (COD)** and **Net 30** are the most commonly used payment terms.
#
# ### **Category Variations:**
# - **Cash on Delivery (COD):** Higher proportion in Clothing and Furniture.
# - **Net 30:** Slightly preferred in Electronics and Machinery.
# - **Net 60 and Prepaid:** Relatively evenly distributed across all categories.
#
# ---
#
# ## **8. Ranking Categories by Total Economic Impact (Value)**
# - **Ranked Categories:**
#   1. **Furniture:** Highest total economic impact.
#   2. **Machinery**
#   3. **Toys**
#   4. **Clothing**
#   5. **Electronics**
#
# - Economic impact varies significantly across categories, with **Furniture** showing notably higher impact compared to others.
#
# ---

# %% [markdown]
# # **Managerial Insights**
#
# ---
#
# ### **1. Trade Imbalances and Specialization**
# - **Observation:** Some countries focus heavily on exports (e.g., Solomon Islands), while others rely on imports (e.g., Zimbabwe). This indicates potential trade imbalances and areas where countries may specialize in specific high-value products.
#
# - **Key Questions for Managers:**
#   - *Which countries should we target for sourcing high-value goods?*
#   - *Are there opportunities in countries that rely on imports to expand our business?*
#
# - **Actionable Insight:**
#   - **Export-heavy countries** present opportunities for sourcing and strategic partnerships.
#   - **Import-heavy countries** offer a growth opportunity for entering new markets and catering to unmet demand.
#
# ---
#
# ### **2. Product Category Dominance**
# - **Observation:** Categories like furniture, machinery, and toys dominate in trade value and volume. Specialized logistics, supply chains, and marketing strategies are crucial for managing these high-value products.
#
# - **Key Questions for Managers:**
#   - *Are we positioned to capitalize on these high-value product categories?*
#   - *Do we have the right logistics strategy in place to optimize distribution for these products?*
#
# - **Actionable Insight:**
#   - **Invest in logistics and distribution channels** to maintain competitiveness in dominant categories.
#   - **Stay ahead of industry trends** by continuously evaluating the needs and opportunities in these high-value segments.
#
# ---
#
# ### **3. Shipping Strategy Optimization**
# - **Observation:** High-value products typically use faster shipping methods (e.g., air), while lower-value or bulk products use cost-efficient options (e.g., sea). However, industries like machinery sometimes prioritize speed over cost, even for heavier items.
#
# - **Key Questions for Managers:**
#   - *Are we optimizing our shipping strategies based on product value and urgency?*
#   - *How can we balance cost vs. speed for different product categories?*
#
# - **Actionable Insight:**
#   - **High-value products** should prioritize speed and security (e.g., air freight).
#   - **Bulk products** can benefit from **cost-efficient methods** like sea freight.
#
# ---
#
# ### **4. Country-Specific Strategies**
# - **Observation:** Different countries exhibit unique trade behaviors. For example, the Solomon Islands have high transaction values and quantities, while Norway deals with niche, high-value goods in smaller quantities.
#
# - **Key Questions for Managers:**
#   - *Are we tailoring our strategies to meet the unique needs of different countries?*
#   - *What markets should we prioritize for high-value or niche products?*
#
# - **Actionable Insight:**
#   - In **Solomon Islands**, focus on **robust supply chain management** to handle large, valuable transactions.
#   - In **Norway and Sri Lanka**, emphasize **quality and premium positioning** over scale.
#   - In **Puerto Rico**, explore **balanced growth strategies** for both volume and value expansion.
#
# ---
#
# ### **5. Payment Terms and Financial Management**
# - **Observation:** Cash on Delivery (COD) and Net 30 terms are common, especially in the furniture and clothing categories, which might indicate higher buyer risk or reliance on immediate payments.
#
# - **Key Questions for Managers:**
#   - *Are we offering the right payment terms for different categories?*
#   - *Do we have sufficient liquidity to support COD-heavy transactions?*
#
# - **Actionable Insight:**
#   - For **COD-heavy categories** like furniture and clothing, **ensure liquidity** to accommodate immediate payments.
#   - For **Net 30-heavy industries** like electronics and machinery, **focus on maintaining strong credit relationships** to ensure steady cash flow.
#
# ---
#
# ### **6. Weight-Based Logistics Optimization**
# - **Observation:** Consistency in maximum weights across shipping methods for most product categories suggests room for efficiency, while categories like machinery and furniture show variance, especially with air freight.
#
# - **Key Questions for Managers:**
#   - *Are there opportunities to standardize shipping weights to improve efficiency?*
#   - *How can we optimize packaging and logistics to reduce costs in heavier categories?*
#
# - **Actionable Insight:**
#   - **Standardize shipping weights** and explore automation to enhance logistics efficiency.
#   - For categories with **weight variance**, re-examine packaging and shipping methods to minimize costs and enhance logistics.
#
# ---
#
# ### **7. Ranking Categories by Economic Impact**
# - **Observation:** Furniture has the highest total economic impact, followed by machinery and toys, indicating a high demand for these products in the global trade ecosystem.
#
# - **Key Questions for Managers:**
#   - *Are we allocating enough resources to our high-impact product categories?*
#   - *How can we further scale our operations in these categories to capture more market share?*
#
# - **Actionable Insight:**
#   - **Prioritize resource allocation** to high-impact categories like furniture and machinery.
#   - Explore **scaling up manufacturing and distribution** to meet growing demand, and **invest in marketing** to further capture market share.
#
# ---
#
# ### Final Reflection:
#
# Each insight presents a strategic opportunity for growth, optimization, or innovation. Managers should **evaluate their current practices** and **adapt strategies** based on these findings to remain competitive in the evolving landscape of global trade.

# %% [markdown]
# # **Recommendations**
#
# ---
#
# ### **1. Data-Driven Decision-Making**
# - **Why it matters:** In today’s fast-paced global market, having real-time insights into trade activities is crucial for staying competitive.
#
# - **Recommendation:**
#   Implement **regular monitoring** and **analysis** of trade data to spot emerging trends. Using **advanced analytics tools** like predictive modeling can enhance the **accuracy of future trade predictions**, enabling better decision-making.
#
# - **Action Steps for Managers:**
#   - Establish a **data analytics team** or partner with an external provider.
#   - Integrate **predictive analytics** to forecast trade trends and adjust strategies proactively.
#   - Continuously refine decision-making processes using insights from **real-time trade data**.
#
# ---
#
# ### **2. Optimize Shipping Methods for Cost Efficiency**
# - **Why it matters:** Shipping costs can significantly impact profit margins, especially for businesses dealing with lower-value goods.
#
# - **Recommendation:**
#   For lower-value goods, explore **cost-effective shipping methods**, such as consolidated shipping or partnerships with local carriers. This can help to **reduce expenses** while ensuring timely delivery.
#
# - **Action Steps for Managers:**
#   - Conduct a **cost-benefit analysis** of different shipping methods based on product value and volume.
#   - Look for **local partnerships** with carriers to reduce international shipping costs.
#   - Consider **bulk or consolidated shipping** options for frequent low-value shipments to maximize savings.
#
# ---
#
# ### **3. Country-Specific Partnerships**
# - **Why it matters:** Engaging in partnerships with local firms in high trade activity regions can provide businesses with better access to local resources, markets, and reduce operational costs.
#
# - **Recommendation:**
#   Develop **strategic partnerships** in countries with **high import/export activities** to capitalize on local market trends. Explore **joint ventures** with local firms to improve market access and minimize risks.
#
# - **Action Steps for Managers:**
#   - Identify **high-activity countries** that align with your business goals.
#   - Build **relationships** with key stakeholders, including local suppliers, distributors, and government entities.
#   - Explore opportunities for **joint ventures** or **alliances** to strengthen local market presence and operational efficiency.
#
# ---
#
# ### Final Thoughts:
#
# Taking a **data-driven approach**, optimizing logistics, and building **country-specific partnerships** will ensure businesses remain competitive and agile in the evolving global trade landscape.

# %% [markdown]
# # **Interpretation:**
#
# ---
#
# ### **1. Intercept:**
# - **Value Interpretation:**
#   The intercept of **5252.53** represents the **baseline estimated Value** when **Quantity is zero**. Even with no quantity, there's still an initial value, which could be attributed to fixed costs or base transaction values.
#
#   - **Key Insight:** This provides a starting point for understanding how additional quantities contribute to the transaction's total value.
#
# ---
#
# ### **2. Coefficients:**
#
# #### **Linear Term Coefficient (0.326):**
# - **What it means:**
#   This coefficient indicates a **positive relationship** between **Quantity** and **Value**. For each additional unit of Quantity, the **Value increases by approximately 0.326 units**.
#
# - **Real-World Impact:**
#   This shows that larger quantities tend to **increase transaction value**. However, it's essential to consider that this effect may not hold consistently at higher quantities.
#
# ---
#
# #### **Quadratic Term Coefficient (-0.0000518):**
# - **What it means:**
#   The **negative quadratic coefficient** suggests a **diminishing return effect**. As the Quantity increases, the **impact on Value decreases**. The negative curvature indicates that the relationship between Quantity and Value isn't a simple linear increase; instead, the **rate of increase slows down** over time.
#
# - **Real-World Impact:**
#   This diminishing effect could be due to factors like **bulk discounts**, **economies of scale**, or **saturation points** where additional quantities add less value.
#
# ---
#
# # **Conclusion:**
#
# ---
#
# The polynomial regression model captures both **linear** and **quadratic effects** between **Quantity** and **Value** for the top 5 countries in the dataset.
#
# ### **Key Takeaways:**
# - **Positive Relationship:** There’s a **general positive correlation** between Quantity and Value. Higher quantities lead to higher values, supporting the intuitive understanding of how trade typically works.
# - **Diminishing Returns:** The diminishing effect means that at higher levels of Quantity, the **rate of increase in value slows down**. This could highlight the **efficiency limits** or other factors such as bulk pricing mechanisms in large transactions.

# %% [markdown]
# # **Managerial Insights | Recommendations**
#
# Based on the analysis, several actionable insights emerge that can guide strategic decision-making:
#
# 1. ### **🎯 Focus on High-Value Trade Partners**
#    - **Key Insight**: Identifying countries with consistently high trade volumes can help businesses **maximize revenue** through strategic partnerships. Forming trade agreements with these key players opens opportunities for sustained growth.
#    - **Actionable Step**: **Governments** and **business leaders** should collaborate to implement policies that foster **long-term economic benefits** with these major trade partners.
#    > **Example**: Strengthening relationships with **export-heavy countries** like the Solomon Islands could enhance sourcing strategies.
#
# 2. ### **💼 Optimize Trade in Dominant Product Categories**
#    - **Key Insight**: Certain product categories, such as **furniture** and **machinery**, contribute significantly to overall trade value. Prioritizing these categories will increase profitability.
#    - **Actionable Step**: Businesses should **refine supply chain efficiency**, implement targeted **marketing strategies**, and **negotiate favorable terms** with suppliers to improve profitability in these sectors.
#    > **Example**: A furniture company might invest in **logistics technology** to reduce delivery times and cut operational costs.
#
# 3. ### **📅 Monitor Seasonal Trends**
#    - **Key Insight**: Trade volumes often **fluctuate seasonally**, and aligning operations with these cycles can increase profitability.
#    - **Actionable Step**: Businesses can adjust **inventory management** and **logistics** to better meet demand during peak seasons. This optimizes **resource allocation** and minimizes inventory costs during slower periods.
#    > **Example**: Retailers could focus on specific **holiday periods** to stock relevant products and adjust marketing efforts accordingly.
#
# 4. ### **🌱 Diversify Product Offerings**
#    - **Key Insight**: While focusing on high-performing product categories is profitable, exploring emerging or niche markets can reduce dependency and increase market share.
#    - **Actionable Step**: Analyze **underperforming categories** or **niche markets** for potential growth opportunities. Investing in emerging products can reduce reliance on highly competitive sectors.
#    > **Example**: A company in the electronics sector might explore the **green energy** market to stay ahead of evolving consumer preferences.
#
# 5. ### **🤖 Adopt Technology-Driven Solutions**
#    - **Key Insight**: Leveraging **data analytics**, **artificial intelligence**, and **automation** can greatly improve decision-making processes. These technologies provide real-time insights into pricing strategies, inventory management, and demand forecasting.
#    - **Actionable Step**: Businesses should invest in **digital transformation** to become more adaptable to market changes. This will lead to **lower operational costs**, enhanced **pricing accuracy**, and improved **inventory management**.
#    > **Example**: Implementing an **AI-based forecasting system** can help predict consumer demand and reduce excess stock or shortages.
#
# ---
#
# ### **Interactive Tips**:
# - Use data visualization tools to create **graphs and charts** that display seasonal trends, product category performance, or trade partner analysis.
# - Implement **dashboards** for tracking trade volumes, supply chain efficiency, and demand predictions in real time.
# - Conduct **what-if analysis** using historical data to anticipate the impact of different trade strategies.
#
# By adopting these strategies, businesses can ensure data-driven decision-making, resulting in stronger trade relations, optimized logistics, and higher profitability.

# %% [markdown]
# # **Data Exploration with Python using Pandas & Numpy Libraries**
# ---

# %% [markdown]
# # 1. Importing Relevant Python Libraries.

# %%
# Import Relevant Python Libraries.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
from sklearn.linear_model import LinearRegression

# %%
# Load the Dataset.
data1=pd.read_csv("D:\\FSM Documents\\Python\\Python Project 1\\Imports_Exports_Dataset.csv")
data1
# Out:
#                              Transaction_ID           Country    Product  \
# 0      e3e70682-c209-4cac-a29f-6fbed82c07cd          Colombia   describe
# 1      f728b4fa-4248-4e3a-8a5d-2f346baa9455             Chile  president
# 2      eb1167b3-67a9-4378-bc65-c1e582e2e662            Turkey        far
# 3      f7c1bd87-4da5-4709-9471-3d60c8a70639  Christmas Island     agency
# 4      e443df78-9558-467f-9ba9-1faf7a024204           Finland     policy
# ...                                     ...               ...        ...
# 14995  48df15a8-0823-4964-8c16-eddf2756f382  Marshall Islands        not
# 14996  31106617-94a6-4646-a001-5e7bd45abc26           Bermuda        air
# 14997  ee485839-fbde-4ced-af18-d98f5e863081          Tanzania       show
# 14998  5acd54aa-ec8c-4055-be8b-a447861a471c            Tuvalu         TV
# 14999  5cc039d0-a052-41fd-bfbb-c9f60c4565ac   North Macedonia       year
#
#       Import_Export  Quantity    Value        Date     Category  \
# ...

# %% [markdown]
# # 2. Description of Data
#
# **1.Data Source & Size:**
#
# Source: The dataset for this project was obtained from Kaggle.
#
# Size: 15,000 records with 16 variables.
#
# **2.Data Type:** This is a Cross-sectional dataset, capturing transactional data at a specific point in time.
#
# **3.Data Dimension:**
#
# Number of Variables: 16
#
# Number of Observations: 15,000
#
# **4.Data Variable Type:**
#
# Text Variables: Transaction_ID, Country, Product, Import_Export, Date, Category, Port, Shipping_Method, Supplier, Customer, Payment_Terms
#
# Number Variables: Integer: Quantity, Customs_Code, Invoice_Number
#
# Decimal: Value, Weight
#
# **5.Data Variable Category:**
#
# Index: Transaction_ID, Invoice_Number (used for identifying each transaction)
#
# Categorical (Nominal): Country, Product, Import_Export, Category, Port, Shipping_Method, Supplier, Customer, Payment_Terms
#
# Categorical (Ordinal):
#
# Non-Categorical: Quantity, Value, Customs_Code, Weight

# %%
# Display the Dimensions of Test Data.
data1.info()
data1.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Transaction_ID   15000 non-null  object
#  1   Country          15000 non-null  object
#  2   Product          15000 non-null  object
#  3   Import_Export    15000 non-null  object
#  4   Quantity         15000 non-null  int64
#  5   Value            15000 non-null  float64
#  6   Date             15000 non-null  object
#  7   Category         15000 non-null  object
#  8   Port             15000 non-null  object
#  9   Customs_Code     15000 non-null  int64
#  10  Weight           15000 non-null  float64
#  11  Shipping_Method  15000 non-null  object
#  12  Supplier         15000 non-null  object
#  13  Customer         15000 non-null  object
#  14  Invoice_Number   15000 non-null  int64
#  15  Payment_Terms    15000 non-null  object
# ...

# %%
# Create an Unique Sample of 100 Observations using Student Roll Number as Random State.
data=data1.sample(n=100, random_state=55057)

# %%
#  Display the Dimensions of Sample Data.
data.shape
# Out:
# (100, 16)

# %%
#  Display Sample Data Information.
display(data)
# Out:
#                              Transaction_ID                Country    Product  \
# 10594  ab1835e0-4073-4471-b726-24d496e6d77a             Montenegro     become
# 6393   44876daa-84d8-4ce5-b110-e56b787079cd             Uzbekistan       well
# 13119  2209bc3e-bcba-48ef-8771-ef3354b5231a      Wallis and Futuna  treatment
# 13902  74841903-8521-4382-a669-8a2731922c9d               Paraguay       sign
# 13569  a5487a73-0324-4a63-b1a0-039f2d248033               Pakistan   specific
# ...                                     ...                    ...        ...
# 5799   8fc08350-ac49-48bd-982c-fb2c0152eb6d                 Zambia      woman
# 8226   b6d773ab-db78-4788-b9fa-ce586050e0ac  Saint Kitts and Nevis       soon
# 6768   5007631f-6b63-419f-9b70-b171a77c6b54                Senegal     middle
# 5159   93057571-1e69-44b0-b54d-83e59e241b8e              Singapore       that
# 13366  567179ef-4f36-4b31-a442-afbb8d291438                Liberia    already
#
# ...

# %%
#  Display the List of Names of the Variables.
list_of_variables = data.columns
print("List of Variables:", list_of_variables)
# Out:
# List of Variables: Index(['Transaction_ID', 'Country', 'Product', 'Import_Export', 'Quantity',
#        'Value', 'Date', 'Category', 'Port', 'Customs_Code', 'Weight',
#        'Shipping_Method', 'Supplier', 'Customer', 'Invoice_Number',
#        'Payment_Terms'],
#       dtype='object')

# %%
#  Identify & Display the List of the following Variables:

# 1. Index Variables (Assuming Transaction is the index variable which is unique for each record)
index_variables = ['Transaction_ID']
print("Index Variables:", index_variables)
# Out:
# Index Variables: ['Transaction_ID']

# %% [markdown]
# **Variable Types:**
# 1) **Text** - Transaction_ID, Country, Product, Import_Export, Date, Category, Port, Shipping_Method, Supplier, Customer, Payment_Terms
# 2) **Number- Integer** - Quantity, Customs_Code, Invoice_Number
# 3) **Number- Decimals** - Value, Weight
#
# **Data Variable Category:**
# 1. **Index**- Transaction_ID, Customs_Code, Invoice_Number, Product, Supplier, Customer
# 2. **Categorical- Nominal** - Import_Export, Category, Shipping_Method, Payment_Terms, Country
# 3. **Categorical- Ordinal** -
# 4. **Non-Categorical**-  Quantity, Value, Date, Port, Weightrt, Weight

# %%
# 2. Categorical Variables - Nominal Type (e.g., Country, Product, Category, Port, Shipping_Method, Supplier, Customer)
categorical_nominal_variables = ['Country', 'Product', 'Category', 'Port', 'Shipping_Method', 'Supplier', 'Customer']
print("Categorical Variables - Nominal Type:", categorical_nominal_variables)
# Out:
# Categorical Variables - Nominal Type: ['Country', 'Product', 'Category', 'Port', 'Shipping_Method', 'Supplier', 'Customer']

# %%
# 3. Categorical Variables - Ordinal Type
categorical_ordinal_variables = ['Payment_Terms']
print("Categorical Variables - Ordinal Type:", categorical_ordinal_variables)
# Out:
# Categorical Variables - Ordinal Type: ['Payment_Terms']

# %%
# 4. Non-Categorical Variables
non_categorical_variables = ['Quantity', 'Value', 'Date', 'Weight']
print("Non-Categorical Variables:", non_categorical_variables)
# Out:
# Non-Categorical Variables: ['Quantity', 'Value', 'Date', 'Weight']

# %%
#  Categorical Variables - Nominal and Ordinal Type, Non-Categorical Variables
categorical_nominal_variables = ['Country', 'Product', 'Category', 'Port', 'Shipping_Method', 'Supplier', 'Customer']
categorical_ordinal_variables = [] 
non_categorical_variables = ['Quantity', 'Value', 'Date', 'Weight']

print("Categorical Variables-Nominal Type:", categorical_nominal_variables)
print("Categorical Variables-Ordinal Type:", categorical_ordinal_variables) 
print("Non-Categorical Variables:", non_categorical_variables)
# Out:
# Categorical Variables-Nominal Type: ['Country', 'Product', 'Category', 'Port', 'Shipping_Method', 'Supplier', 'Customer']
# Categorical Variables-Ordinal Type: []
# Non-Categorical Variables: ['Quantity', 'Value', 'Date', 'Weight']

# %% [markdown]
# # **3.Problem Statement**
# The dataset used in this analysis contains detailed imports and exports data. The goal is to thoroughly explore, clean, and analyze this dataset to uncover meaningful patterns and insights related to trade statistics. Utilizing the powerful Pandas and Numpy libraries, we will perform data wrangling, visualization, and in-depth analysis to derive actionable insights that can inform decision-making.
#
# **Objectives**
# **Data Loading and Inspection:** Import the dataset and review its structure to understand the types of information it contains.
#
# **Data Cleaning:** Identify and address any missing values or inconsistencies within the dataset to ensure data quality.
#
# **Data Sampling:** Randomly select 2,000 records from the dataset for a more focused analysis.
#
# **Exploratory Data Analysis (EDA):** Utilize descriptive statistics and visualizations to explore the main characteristics of the data.
#
# **Feature Engineering:** Develop new features from the existing data to enhance the analysis and improve predictive capabilities.
#
# **Insights and Recommendations:** Summarize the key findings and provide actionable, data-driven recommendations based on the analysis.

# %% [markdown]
# # 4. Analysis of Data

# %%
# .1. Subset and Display the Non-Categorical Variables
non_categorical_subset = data[non_categorical_variables]
print("Non-Categorical Subset:", non_categorical_subset)
# Out:
# Non-Categorical Subset:        Quantity    Value        Date   Weight
# 10594      2327  6895.52  08-01-2021   278.96
# 6393       9515  4468.59  13-02-2023   886.73
# 13119      6794  4789.81  13-05-2020  1999.40
# 13902      2791  9728.56  07-08-2021   380.50
# 13569      6495  9419.58  04-06-2024  3711.72
# ...         ...      ...         ...      ...
# 5799       2870  8210.67  07-12-2022  3564.83
# 8226       7257  1357.17  18-09-2020  3128.54
# 6768       1852  5407.27  13-06-2023   169.48
# 5159       9730  2332.72  12-11-2022  1207.13
# 13366      3854  9715.62  23-12-2021  3899.17
#
# [100 rows x 4 columns]

# %%
data[non_categorical_variables]
# Out:
#        Quantity    Value        Date   Weight
# 10594      2327  6895.52  08-01-2021   278.96
# 6393       9515  4468.59  13-02-2023   886.73
# 13119      6794  4789.81  13-05-2020  1999.40
# 13902      2791  9728.56  07-08-2021   380.50
# 13569      6495  9419.58  04-06-2024  3711.72
# ...         ...      ...         ...      ...
# 5799       2870  8210.67  07-12-2022  3564.83
# 8226       7257  1357.17  18-09-2020  3128.54
# 6768       1852  5407.27  13-06-2023   169.48
# 5159       9730  2332.72  12-11-2022  1207.13
# 13366      3854  9715.62  23-12-2021  3899.17
#
# [100 rows x 4 columns]

# %%
# 2. Display the Descriptive Statistics of the Non-Categorical Subset
non_categorical_subset.describe()
# Out:
#           Quantity        Value      Weight
# count   100.000000   100.000000   100.00000
# mean   5236.070000  5161.117800  2446.36420
# std    2693.107072  2721.817751  1435.48422
# min     338.000000   357.150000    78.30000
# 25%    2783.250000  2859.087500  1164.20500
# 50%    5039.000000  5359.440000  2495.21000
# 75%    7377.500000  7473.240000  3655.83500
# max    9952.000000  9999.130000  4978.21000

# %%
non_categorical_stats = non_categorical_subset.describe()
print("Descriptive Statistics of Non-Categorical Variables:\n", non_categorical_stats)
# Out:
# Descriptive Statistics of Non-Categorical Variables:
#            Quantity        Value      Weight
# count   100.000000   100.000000   100.00000
# mean   5236.070000  5161.117800  2446.36420
# std    2693.107072  2721.817751  1435.48422
# min     338.000000   357.150000    78.30000
# 25%    2783.250000  2859.087500  1164.20500
# 50%    5039.000000  5359.440000  2495.21000
# 75%    7377.500000  7473.240000  3655.83500
# max    9952.000000  9999.130000  4978.21000

# %%
# Subset and Display the Categorical Variables
categorical_subset = data[categorical_nominal_variables]
print("Categorical Subset:\n", categorical_subset)
# Out:
# Categorical Subset:
#                       Country    Product     Category                Port  \
# 10594             Montenegro     become         Toys         Crystalbury
# 6393              Uzbekistan       well    Machinery     East Frankshire
# 13119      Wallis and Futuna  treatment    Furniture    South Scottville
# 13902               Paraguay       sign    Machinery        Gilbertmouth
# 13569               Pakistan   specific    Furniture           Welchside
# ...                      ...        ...          ...                 ...
# 5799                  Zambia      woman         Toys           Moramouth
# 8226   Saint Kitts and Nevis       soon  Electronics           East Adam
# 6768                 Senegal     middle    Furniture       South Jessica
# 5159               Singapore       that         Toys           Juanmouth
# 13366                Liberia    already         Toys  North Kennethmouth
#
#       Shipping_Method                    Supplier         Customer
# ...

# %%
data[categorical_nominal_variables]
# Out:
#                      Country    Product     Category                Port  \
# 10594             Montenegro     become         Toys         Crystalbury
# 6393              Uzbekistan       well    Machinery     East Frankshire
# 13119      Wallis and Futuna  treatment    Furniture    South Scottville
# 13902               Paraguay       sign    Machinery        Gilbertmouth
# 13569               Pakistan   specific    Furniture           Welchside
# ...                      ...        ...          ...                 ...
# 5799                  Zambia      woman         Toys           Moramouth
# 8226   Saint Kitts and Nevis       soon  Electronics           East Adam
# 6768                 Senegal     middle    Furniture       South Jessica
# 5159               Singapore       that         Toys           Juanmouth
# 13366                Liberia    already         Toys  North Kennethmouth
#
#       Shipping_Method                    Supplier         Customer
# ...

# %%
 # Display the Descriptive Statistics of the any one Categorical Subset.
descriptive_stats_categorical = data['Category'].describe()
print(f"Analysis for {descriptive_stats_categorical}:")
# Out:
# Analysis for count           100
# unique            5
# top       Furniture
# freq             24
# Name: Category, dtype: object:

# %% [markdown]
# ### Categorical Data
#
# 1. **Count**: The total number of occurrences of each category in the dataset, providing a basic understanding of distribution among categories.
#
# 2. **Frequency**: The number of times each category appears in the dataset, allowing for easy comparison between categories.
#
# 3. **Proportion**: The fraction of the total that each category represents, calculated by dividing the count of each category by the total count, useful for understanding relative sizes.
#
# 4. **Minimum**: The lowest value in a categorical dataset, often relevant in ordered categories, indicating the least significant category.
#
# 5. **Maximum**: The highest value in a categorical dataset, highlighting the most significant category when categories are ordered.
#
# 6. **Mode**: The category that appears most frequently in the dataset, providing insight into the most common observation.
#
# 7. **Rank**: The order of categories based on a specific criterion, allowing for comparison of categories relative to one another.
#
# 8. **Correlation**: Measures the strength and direction of the relationship between two categorical variables, often assessed through contingency tables.
#
# ### Chi-squared Test
#
# 9. **Goodness of Fit**: A statistical test used to determine if observed frequencies match expected frequencies for a single categorical variable, assessing how well the data fits a specified distribution.
#
# 10. **Test of Independence**: A statistical test that evaluates whether two categorical variables are independent or associated, often using a contingency table to assess relationships between variables.
#
# ### Non-Parametric Tests
#
# 11. **Mann-Whitney**: A non-parametric test that compares differences between two independent groups based on ranks, suitable for ordinal data or non-normally distributed continuous data.
#
# 12. **Wilcoxon**: A non-parametric test that compares two related samples or matched groups, assessing differences in ranks without assuming normality.
#
# 13. **Kruskal-Wallis**: A non-parametric test that compares three or more independent groups based on ranks, useful when assumptions of ANOVA are not met.
#
# 14. **Friedman**: A non-parametric test that compares three or more related groups, assessing differences in ranks across multiple observations.
#
# ### Regression with Categorical Variables
#
# 15. **Logistic Regression**: A statistical method used to model binary outcomes based on one or more predictor variables, allowing for prediction of the probability of a particular outcome occurring.
#
# ### Visualizations
#
# 16. **Bar Chart**: A graphical representation of categorical data using bars to show the frequency or proportion of each category, making it easy to compare different groups visually.
#
# 17. **Histogram**: A graphical representation of the distribution of numerical data, where bars represent frequency counts for ranges of values, providing insight into data distribution.
#
# 18. **Pie Chart**: A circular chart divided into slices, illustrating the proportion of each category relative to the whole, helpful for visualizing categorical data distribution.

# %%
# Frequency
frequency = data['Category'].value_counts(normalize=True)
frequency
# Out:
# Category
# Furniture      0.24
# Electronics    0.22
# Toys           0.20
# Machinery      0.17
# Clothing       0.17
# Name: proportion, dtype: float64

# %%
# Proportion
proportion = frequency * 100
proportion
# Out:
# Category
# Furniture      24.0
# Electronics    22.0
# Toys           20.0
# Machinery      17.0
# Clothing       17.0
# Name: proportion, dtype: float64

# %%
# Mode
mode = data['Category'].mode()[0]
mode
# Out:
# 'Furniture'

# %%
# Find the minimum value of data
min_value = data['Value'].min()

# Find the maximum value of Value
max_value = data['Value'].max()

# Display the minimum and maximum values
print(f"Minimum value: {min_value}")
print(f"Maximum value: {max_value}")
# Out:
# Minimum value: 357.15
# Maximum value: 9999.13

# %%
# Find Rank of the value
Rank=data['Quantity'].rank()
Rank
# Out:
# 10594    20.0
# 6393     94.0
# 13119    69.0
# 13902    26.0
# 13569    66.0
#          ...
# 5799     27.0
# 8226     74.0
# 6768     14.0
# 5159     97.0
# 13366    32.0
# Name: Quantity, Length: 100, dtype: float64

# %%
# Performing a t-test to compare the means of import and export values in a dataset using Python.

from scipy import stats

# Subsetting data for imports and exports
import_data = data[data['Import_Export'] == 'Import']['Value']
export_data = data[data['Import_Export'] == 'Export']['Value']

# t-test to compare means of import vs export values
t_stat, p_value = stats.ttest_ind(import_data, export_data)

print("t-statistic:", t_stat)
print("p-value:", p_value)
# Out:
# t-statistic: -0.30625279656690463
# p-value: 0.7600618562032236

# %%
# Chi-squared test of between Independence of Country and Import_Export.

country_import_export_crosstab = pd.crosstab(data['Country'], data['Import_Export'])
chi2_stat, p_val, dof, expected = stats.chi2_contingency(country_import_export_crosstab)

print("Chi-Square Statistic:", chi2_stat)
print("P-Value:", p_val)
# Out:
# Chi-Square Statistic: 82.55501878690285
# P-Value: 0.5241575019681016

# %%
# Use the Mann-Whitney U Test to compare the distributions of import and export values in a dataset.

from scipy.stats import mannwhitneyu

# Separate the two groups
import_values = data[data['Import_Export'] == 'Import']['Value']
export_values = data[data['Import_Export'] == 'Export']['Value']

# Mann-Whitney U Test
stat, p_value = mannwhitneyu(import_values, export_values)

print(f'Mann-Whitney U Test statistic: {stat}, p-value: {p_value}')
# Out:
# Mann-Whitney U Test statistic: 1201.0, p-value: 0.7794027368071352

# %%
# Use non-parametric tests like Mann-Whitney U, Wilcoxon, and Kruskal-Wallis to compare groups based on different variables in a dataset

from scipy.stats import mannwhitneyu, wilcoxon, kruskal, friedmanchisquare

# 1. Mann-Whitney U Test
# Compare Quantity between Air and Sea shipping methods
shipping_air = data[data['Shipping_Method'] == 'Air']['Quantity']
shipping_sea = data[data['Shipping_Method'] == 'Sea']['Quantity']  # Assuming 'Sea' exists

mannwhitneyu_result = mannwhitneyu(shipping_air, shipping_sea)
print('Mann-Whitney U Test between Air and Sea Shipping:', mannwhitneyu_result)

# 2. Wilcoxon Signed-Rank Test
# Compare Quantity for Air Shipping before and after April 2023
before_date_air = data[(data['Date'] < '2023-04-01') & (data['Shipping_Method'] == 'Air')]['Quantity']
after_date_air = data[(data['Date'] >= '2023-04-01') & (data['Shipping_Method'] == 'Air')]['Quantity']

# Ensure both samples are the same size (Wilcoxon requires paired data)
min_len_air = min(len(before_date_air), len(after_date_air))
wilcoxon_result = wilcoxon(before_date_air.iloc[:min_len_air], after_date_air.iloc[:min_len_air])
print('Wilcoxon Signed-Rank Test for Air Shipping before and after April 2023:', wilcoxon_result)

# 3. Kruskal-Wallis H Test
# Compare Quantity across different Product categories (e.g., Machinery, Electronics, Clothing)
product_categories = ['Machinery', 'Electronics', 'Clothing']
product_groups = [data[data['Category'] == product]['Quantity'] for product in product_categories]

kruskal_result = kruskal(*product_groups)
print('Kruskal-Wallis H Test across Product Categories:', kruskal_result)
# Out:
# Mann-Whitney U Test between Air and Sea Shipping: MannwhitneyuResult(statistic=660.0, pvalue=0.02962564236366422)
# Wilcoxon Signed-Rank Test for Air Shipping before and after April 2023: WilcoxonResult(statistic=16.0, pvalue=0.49609375)
# Kruskal-Wallis H Test across Product Categories: KruskalResult(statistic=3.7161654135338154, pvalue=0.15597138675906363)

# %%
# Check the size of each group first

date_group1_air = data[(data['Date'] == '07-12-2023') & (data['Shipping_Method'] == 'Air')]['Quantity']
date_group2_air = data[(data['Date'] == '04-04-2023') & (data['Shipping_Method'] == 'Air')]['Quantity']
date_group3_air = data[(data['Date'] == '21-08-2024') & (data['Shipping_Method'] == 'Air')]['Quantity']

# Check the number of entries in each group

print("Group 1 size:", len(date_group1_air))
print("Group 2 size:", len(date_group2_air))
print("Group 3 size:", len(date_group3_air))

# Ensure that all groups have values, and the test can proceed

if len(date_group1_air) > 1 and len(date_group2_air) > 1 and len(date_group3_air) > 1:
    friedman_result = friedmanchisquare(date_group1_air, date_group2_air, date_group3_air)
    print('Friedman Test for Air Shipping across different dates:', friedman_result)
else:
    print("Error: One or more groups do not have sufficient data for the Friedman test.")
# Out:
# Group 1 size: 0
# Group 2 size: 0
# Group 3 size: 0
# Error: One or more groups do not have sufficient data for the Friedman test.

# %%
# Regression with Categorical Variables
# Build an OLS regression model with interaction terms between Country and Shipping_Method

import statsmodels.formula.api as smf

# Using a formula to include interaction terms between Country and Shipping_Method
model = smf.ols('Value ~ Country + Shipping_Method + Category + Country:Shipping_Method', data=data).fit()

# Print the summary of the model
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  Value   R-squared:                       0.962
# Model:                            OLS   Adj. R-squared:                 -0.258
# Method:                 Least Squares   F-statistic:                    0.7882
# Date:                Mon, 07 Oct 2024   Prob (F-statistic):              0.710
# Time:                        01:38:00   Log-Likelihood:                -768.96
# No. Observations:                 100   AIC:                             1732.
# Df Residuals:                       3   BIC:                             1985.
# Df Model:                          96
# Covariance Type:            nonrobust
# ...
#                                                                                       coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------------------------------------------
# ...

# %%
# Count the occurrences of each category in the 'Import_Export' column 
import_export_counts = data['Import_Export'].value_counts()

# Plotting the pie chart
plt.figure(figsize=(6, 6))
plt.pie(import_export_counts, labels=import_export_counts.index, autopct='%1.1f%%', startangle=90, colors=['#66b3ff','#99ff99'])
plt.title('Distribution of Imports and Exports')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()

# %%
# Count the occurrences of each category in 'Shipping_Method'
shipping_method_counts = data['Shipping_Method'].value_counts()

# Plot the bar graph 
plt.figure(figsize=(8, 6))
shipping_method_counts.plot(kind='bar', color='skyblue')

# Add titles and labels
plt.title('Frequency of Shipping Methods')
plt.xlabel('Shipping Method')
plt.ylabel('Count')

# Show the plot
plt.show()

# %%
# Group by Shipping Method and Country
grouped_by_country = data.groupby(['Country', 'Shipping_Method']).size().unstack()

# Plot a grouped bar chart
grouped_by_country.plot(kind='bar', figsize=(12, 8))

# Add titles and labels
plt.title('Shipping Methods by Country')
plt.xlabel('Country')
plt.ylabel('Count')
plt.legend(title='Shipping Method', bbox_to_anchor=(1.05, 1), loc='upper left')

plt.tight_layout()
plt.show()

# %%
# Encoding 'Shipping_Method' to numerical values
data['Shipping_Method_Encoded'] = data['Shipping_Method'].astype('category').cat.codes

# Plot histogram for 'Shipping_Method_Encoded'
plt.figure(figsize=(8, 6))
plt.hist(data['Shipping_Method_Encoded'], bins=range(data['Shipping_Method_Encoded'].nunique() + 1), color='skyblue', edgecolor='black', alpha=0.7)

# Add labels
plt.title('Histogram of Shipping Methods (Encoded)')
plt.xlabel('Shipping Method (Encoded)')
plt.ylabel('Frequency')

# Show the plot
plt.show()

# %% [markdown]
# ### Non-Categorical Data
#
# **Measures of Central Tendency**
# - **Minimum**: The smallest value in the dataset, indicating the lowest point of observation.
# - **Maximum**: The largest value in the dataset, representing the highest point of observation.
# - **Mean**: The arithmetic average calculated by summing all values and dividing by the number of observations.
# - **Median**: The middle value in a sorted dataset, providing a measure that is less affected by outliers than the mean.
# - **Mode**: The value that appears most frequently in the dataset, useful for identifying the most common observation.
# - **Percentile**: A measure indicating the value below which a given percentage of data falls, helping to understand distribution.
#
# **Measures of Dispersion**
# - **Range**: The difference between the maximum and minimum values, reflecting the spread of the data.
# - **Standard Deviation**: A statistic that measures how much individual data points deviate from the mean, indicating data variability.
# - **Skewness**: A measure of the asymmetry of the data distribution, indicating whether data points are skewed left or right.
# - **Kurtosis**: A statistic that measures the "tailedness" of the data distribution, indicating the presence of outliers.
# - **Correlation**: A measure that describes the strength and direction of the relationship between two variables.
#
# **Composite Measure**
# - **Coefficient of Variation**: A standardized measure of dispersion calculated as the ratio of the standard deviation to the mean, expressed as a percentage, useful for comparing variability across datasets.
# - **Confidence Interval**: A range of values that likely contains the true population parameter, providing a measure of estimation uncertainty.
#
# **Test of Mean**
# - **t-test**: A statistical test used to compare the means of two groups to determine if they are significantly different from each other.
# - **ANOVA**: Analysis of variance, used to compare the means of three or more groups to assess if at least one differs significantly.
#
# **Test of Variance**
# - **F-test**: A statistical test used to compare the variances of two groups to determine if they are significantly different.
# - **Levene's Test**: Assesses whether two or more groups have equal variances, useful for validating ANOVA assumptions.
# - **Bartlett's Test**: A test for equal variances across multiple groups, sensitive to departures from normality.
#
# **Test of Proportion**
# - **z-test**: A statistical test used to determine if the proportion in a single sample significantly differs from a known population proportion.
# - **Chi-squared test**: A statistical test that assesses the association between categorical variables by comparing observed and expected frequencies.
#
# **Test of Correlation**
# - **t-test for correlation**: Used to assess the significance of the correlation coefficient, determining if the observed correlation between two variables is statistically significant.
#
# **Test of Normality**
# - **Shapiro-Wilk**: A statistical test used to determine if a dataset is normally distributed, based on sample size and data characteristics.
# - **Kolmogorov-Smirnov**: Compares the sample distribution to a reference distribution to assess goodness-of-fit and normality.
# - **Anderson-Darling**: A test for normality that gives more weight to the tails of the distribution, making it sensitive to deviations.
# - **Jarque-Bera**: Tests for normality by evaluating skewness and kurtosis, assessing whether a dataset follows a normal distribution.
#
# **Non-Parametric Tests**
# - **Mann-Whitney**: A non-parametric test that compares the differences between two independent groups without assuming normality.
# - **Wilcoxon**: A non-parametric test that compares two related samples, assessing whether their population mean ranks differ.
# - **Kruskal-Wallis**: A non-parametric test used to compare three or more independent groups when normality cannot be assumed.
# - **Friedman**: A non-parametric test for comparing three or more related groups, assessing differences in ranks across multiple observations.
#
# **Regression**
# - **Cross-sectional Data**: Observations collected at a single point in time, useful for analyzing relationships and effects at that moment.
# - **Time-series Data**: Observations collected over time at regular intervals, ideal for analyzing trends and patterns across different time periods.
# - **Panel Data**: A combination of cross-sectional and time-series data, allowing for more comprehensive analyses by observing multiple subjects over time.
#
# **Polynomial Regression**
# - **Cross-sectional Data**: A regression model that fits a polynomial equation to cross-sectional data, capturing non-linear relationships between variables.
#
# **Scatter Plot**: A graphical representation of two continuous variables, displaying points to reveal potential relationships and trends.
# **Line Plot**: A visualization that connects data points with lines, effectively illustrating trends or changes over time.
# **Box-Whisker Plot**: A graphic that summarizes data distribution, showing the median, quartiles, and potential outliers, useful for comparing distributions.

# %%
# Measures of Dispersion {Range | Standard Deviation | Skewness | Kurtosis | Correlation}

import pandas as pd

# Select numerical columns only
numerical_data = data.select_dtypes(include='number')

# Calculate all metrics
result = {
    'Range': numerical_data.max() - numerical_data.min(),
    'Standard Deviation': numerical_data.std(),
    'Skewness': numerical_data.skew(),
    'Kurtosis': numerical_data.kurt(),
    'Correlation': numerical_data.corr()
}

print(result)
# Out:
# {'Range': Quantity                       9614.00
# Value                          9641.98
# Customs_Code                 879992.00
# Weight                         4899.91
# Invoice_Number             98664631.00
# Shipping_Method_Encoded           2.00
# dtype: float64, 'Standard Deviation': Quantity                   2.693107e+03
# Value                      2.721818e+03
# Customs_Code               2.723105e+05
# Weight                     1.435484e+03
# Invoice_Number             2.727892e+07
# Shipping_Method_Encoded    7.977240e-01
# dtype: float64, 'Skewness': Quantity                  -0.006363
# Value                     -0.001658
# Customs_Code              -0.118423
# Weight                    -0.033550
# Invoice_Number            -0.094620
# Shipping_Method_Encoded   -0.182736
# dtype: float64, 'Kurtosis': Quantity                  -1.077285
# Value                     -1.068445
# Customs_Code              -1.358589
# Weight                    -1.174136
# ...

# %%
# Measures of Central Tendency {Minimum | Maximum | Mean | Median | Mode | Percentile}

import pandas as pd

# Select numerical columns only
numerical_data = data.select_dtypes(include='number')

# Calculate all central tendency metrics
result = {
    'Minimum': numerical_data.min(),
    'Maximum': numerical_data.max(),
    'Mean': numerical_data.mean(),
    'Median': numerical_data.median(),
    'Mode': numerical_data.mode().iloc[0],  # Taking the first mode
    'Percentile (25th)': numerical_data.quantile(0.25),
    'Percentile (75th)': numerical_data.quantile(0.75)
}

print(result)
# Out:
# {'Minimum': Quantity                      338.00
# Value                         357.15
# Customs_Code               115839.00
# Weight                         78.30
# Invoice_Number             932911.00
# Shipping_Method_Encoded         0.00
# dtype: float64, 'Maximum': Quantity                       9952.00
# Value                          9999.13
# Customs_Code                 995831.00
# Weight                         4978.21
# Invoice_Number             99597542.00
# Shipping_Method_Encoded           2.00
# dtype: float64, 'Mean': Quantity                   5.236070e+03
# Value                      5.161118e+03
# Customs_Code               5.847848e+05
# Weight                     2.446364e+03
# Invoice_Number             4.905179e+07
# Shipping_Method_Encoded    1.100000e+00
# dtype: float64, 'Median': Quantity                       5039.00
# Value                          5359.44
# Customs_Code                 601699.50
# Weight                         2495.21
# ...

# %%
# Composite Measure {Coefficient of Variation | Confidence Interval}

# Select numerical columns
numerical_data = data.select_dtypes(include='number')

# Calculate Coefficient of Variation (CV = std / mean)
cv = numerical_data.std() / numerical_data.mean()

# Calculate 95% Confidence Interval (mean ± 1.96 * (std / sqrt(n)))
confidence_interval = stats.norm.interval(0.95, loc=numerical_data.mean(), scale=numerical_data.std()/len(numerical_data)**0.5)

# Display results
result = {'Coefficient of Variation': cv, '95% Confidence Interval': confidence_interval}
print(result)
# Out:
# {'Coefficient of Variation': Quantity                   0.514337
# Value                      0.527370
# Customs_Code               0.465659
# Weight                     0.586783
# Invoice_Number             0.556125
# Shipping_Method_Encoded    0.725204
# dtype: float64, '95% Confidence Interval': (array([4.70823071e+03, 4.62765132e+03, 5.31412886e+05, 2.16501446e+03,
#        4.37052216e+07, 9.43648962e-01]), array([5.76390929e+03, 5.69458428e+03, 6.38156654e+05, 2.72771394e+03,
#        5.43983633e+07, 1.25635104e+00]))}

# %%
#Test of Mean {t | ANOVA}
# ANOVA Compare Value Across Different Product Categories

product_groups = [group['Value'].values for name, group in data.groupby('Product')]

f_stat, p_value = stats.f_oneway(*product_groups)

print("ANOVA F-statistic:", f_stat)
print("p-value:", p_value)
# Out:
# ANOVA F-statistic: 6.597945869988232
# p-value: 0.14043256505365628

# %%
# Test of Variance {F | Levene | Bartlett}
import pandas as pd
from scipy import stats

# Test functions for variance comparison
def variance_tests(data, group_column, value_column, test_name):
    groups = [group[value_column].values for _, group in data.groupby(group_column)]
    
    if test_name == 'Levene':
        stat, p_value = stats.levene(*groups)
    elif test_name == 'Bartlett':
        stat, p_value = stats.bartlett(*groups)
    return stat, p_value

# F-Test for 'Quantity' between 'Import' and 'Export'
import_export_f_stat, import_export_p_value = stats.levene(
    data[data['Import_Export'] == 'Import']['Quantity'],
    data[data['Import_Export'] == 'Export']['Quantity']
)

# Levene's Test for 'Weight' across 'Product' categories
levene_stat, levene_p_value = variance_tests(data, 'Product', 'Weight', 'Levene')

# Bartlett's Test for 'Value' across 'Product' categories
bartlett_stat, bartlett_p_value = variance_tests(data, 'Product', 'Value', 'Bartlett')

# Structured output
output = f"""
F-Test (Quantity: Import vs Export):
  F-Statistic: {import_export_f_stat:.4f}, p-Value: {import_export_p_value:.4e}

Levene's Test (Weight by Product):
  Levene-Statistic: {levene_stat:.4f}, p-Value: {levene_p_value:.4e}

Bartlett's Test (Value by Product):
  Bartlett-Statistic: {bartlett_stat:.4f}, p-Value: {bartlett_p_value:.4e}
"""

# Print results
print(output)
# Out:
# F-Test (Quantity: Import vs Export):
#   F-Statistic: 2.2136, p-Value: 1.4001e-01
#
# Levene's Test (Weight by Product):
#   Levene-Statistic: 629725973013114293350500925440.0000, p-Value: 1.5880e-30
#
# Bartlett's Test (Value by Product):
#   Bartlett-Statistic: nan, p-Value: nan
# C:\Users\rohan\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:3787: RuntimeWarning: Degrees of freedom <= 0 for slice
#   return _methods._var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# C:\Users\rohan\anaconda3\Lib\site-packages\numpy\core\_methods.py:198: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# C:\Users\rohan\anaconda3\Lib\site-packages\scipy\stats\_morestats.py:3061: RuntimeWarning: divide by zero encountered in divide
#   denom = 1.0 + 1.0/(3*(k - 1)) * ((np.sum(1.0/(Ni - 1.0), axis=0)) -

# %%
# Test of Proportion {z | Chi-sq}

import pandas as pd
from statsmodels.stats.proportion import proportions_ztest
from scipy import stats

# Z-Test for Proportion
import_count = sum(data['Import_Export'] == 'Import')
export_count = sum(data['Import_Export'] == 'Export')
z_stat, p_value_z = proportions_ztest([import_count, export_count], [len(data)]*2)

# Chi-Square Test
chi2_stat, p_value_chi, dof, expected = stats.chi2_contingency(pd.crosstab(data['Import_Export'], data['Product']))

# Output results
output = f"""
Z-Test for Proportion (Import vs Export):
  Z-Statistic: {z_stat:.4f}, p-Value: {p_value_z:.4e}

Chi-Square Test (Import_Export by Product):
  Chi2-Statistic: {chi2_stat:.4f}, p-Value: {p_value_chi:.4e}
  Degrees of Freedom: {dof}
"""
print(output)
# Out:
# Z-Test for Proportion (Import vs Export):
#   Z-Statistic: -1.1314, p-Value: 2.5790e-01
#
# Chi-Square Test (Import_Export by Product):
#   Chi2-Statistic: 97.9871, p-Value: 4.5284e-01
#   Degrees of Freedom: 97

# %%
# Test of Correlation {t}

import pandas as pd
from scipy import stats

# Example: Correlation between 'Quantity' and 'Value'
corr, p_value = stats.pearsonr(data['Quantity'], data['Value'])

# Output results
output = f"""
Correlation Test (Quantity vs Value):
  Correlation Coefficient: {corr:.4f}
  p-Value: {p_value:.4e}
"""
print(output)
# Out:
# Correlation Test (Quantity vs Value):
#   Correlation Coefficient: -0.0679
#   p-Value: 5.0238e-01

# %%
#  The normality of the 'Quantity' column using Shapiro-Wilk, Kolmogorov-Smirnov, Anderson-Darling, and Jarque-Bera tests.

from scipy import stats

# Select the 'Quantity' column for testing
quantity = data['Quantity']

# 1. Shapiro-Wilk Test
shapiro_test = stats.shapiro(quantity)

# 2. Kolmogorov-Smirnov Test
ks_test = stats.kstest(quantity, 'norm')

# 3. Anderson-Darling Test
anderson_test = stats.anderson(quantity)

# 4. Jarque-Bera Test
jarque_bera_test = stats.jarque_bera(quantity)

# Display the results in a structured format
print("Statistical Test Results:")
print("-" * 30)

print(f"1. Shapiro-Wilk Test:")
print(f"   Statistic: {shapiro_test.statistic:.4f}")
print(f"   p-value: {shapiro_test.pvalue:.4f}")

print("-" * 30)

print(f"2. Kolmogorov-Smirnov Test:")
print(f"   Statistic: {ks_test.statistic:.4f}")
print(f"   p-value: {ks_test.pvalue:.4f}")

print("-" * 30)

print(f"3. Anderson-Darling Test:")
print(f"   Statistic: {anderson_test.statistic:.4f}")
print(f"   Critical Values: {anderson_test.critical_values}")
print(f"   Significance Level: {anderson_test.significance_level}")

print("-" * 30)

print(f"4. Jarque-Bera Test:")
print(f"   Statistic: {jarque_bera_test.statistic:.4f}")
print(f"   p-value: {jarque_bera_test.pvalue:.4f}")
# Out:
# Statistical Test Results:
# ------------------------------
# 1. Shapiro-Wilk Test:
#    Statistic: 0.9638
#    p-value: 0.0076
# ------------------------------
# 2. Kolmogorov-Smirnov Test:
#    Statistic: 1.0000
#    p-value: 0.0000
# ------------------------------
# 3. Anderson-Darling Test:
#    Statistic: 0.8440
#    Critical Values: [0.555 0.632 0.759 0.885 1.053]
#    Significance Level: [15.  10.   5.   2.5  1. ]
# ------------------------------
# 4. Jarque-Bera Test:
#    Statistic: 4.8929
#    p-value: 0.0866

# %%
# Non-Parametric Tests {Mann-Whitney | Wilcoxon | Kruskal-Wallis | Friedman}

import pandas as pd
from scipy import stats

# Mann-Whitney U Test (e.g., comparing 'Quantity' between 'Import' and 'Export')
import_qty = data[data['Import_Export'] == 'Import']['Quantity']
export_qty = data[data['Import_Export'] == 'Export']['Quantity']
u_stat, p_value_mw = stats.mannwhitneyu(import_qty, export_qty)

# Kruskal-Wallis Test (e.g., comparing 'Value' across different 'Product' categories)
kw_stat, p_value_kw = stats.kruskal(*[group['Value'].values for _, group in data.groupby('Product')])

# Output results
output = f"""
Mann-Whitney U Test (Quantity: Import vs Export):
  U-Statistic: {u_stat:.4f}, p-Value: {p_value_mw:.4e}

Kruskal-Wallis Test (Value by Product):
  KW-Statistic: {kw_stat:.4f}, p-Value: {p_value_kw:.4e}
"""
print(output)
# Out:
# Mann-Whitney U Test (Quantity: Import vs Export):
#   U-Statistic: 1350.0000, p-Value: 4.5720e-01
#
# Kruskal-Wallis Test (Value by Product):
#   KW-Statistic: 98.7529, p-Value: 4.3136e-01

# %%
# Scatter plot of Quantity vs Value   

plt.scatter(data['Quantity'], data['Value'])
plt.title('Scatter Plot')
plt.xlabel('Quantity')
plt.ylabel('Value')
plt.show()

# %%
# Convert the 'Date' column to datetime
data['Date'] = pd.to_datetime(data['Date'], format='%d-%m-%Y')

# Sort data by 'Date' for line plot
data = data.sort_values(by='Date')

# Plot Quantity over time
plt.figure(figsize=(10, 6))
plt.plot(data['Date'], data['Quantity'], marker='o', color='b', label='Quantity')

# Add titles and labels
plt.title('Quantity Over Time')
plt.xlabel('Date')
plt.ylabel('Quantity')
plt.grid(True)

# Show the plot
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set the style for seaborn
sns.set(style="whitegrid")

# Create a figure to plot multiple box plots
plt.figure(figsize=(12, 6))

# Plotting multiple box plots for 'Quantity', 'Value', and 'Weight'
sns.boxplot(data=data[['Quantity', 'Value', 'Weight']])

# Set plot title and labels
plt.title('Box-Whisker Plot for Quantity, Value, and Weight', fontsize=14)
plt.xlabel('Variables', fontsize=12)
plt.ylabel('Values', fontsize=12)

# Display the plot
plt.show()

# %% [markdown]
# ### Managerial Insights | Recommendations
#
# Based on the analysis, several key insights can guide managerial decisions:
#
# 1. **Focus on High-Value Trade Partners**: Identifying and targeting countries with consistently high trade volumes can significantly enhance strategic partnerships. By forming trade agreements with these key players, businesses can maximize revenue potential. Additionally, governments should consider policies that promote sustained growth with these major trade partners, ensuring long-term economic benefits.
#
# 2. **Optimize Trade in Dominant Product Categories**: Certain product categories contribute significantly to overall trade value. Businesses should prioritize investment and marketing efforts in these high-performing sectors. This could involve enhancing supply chain efficiency, refining pricing strategies, and negotiating favorable terms with suppliers and customers to drive higher profitability.
#
# 3. **Monitor Seasonal Trends**: Analyzing fluctuations in trade volumes reveals important seasonal patterns. By aligning operations, inventory management, and logistics with these trends, businesses can better meet demand during peak periods, optimizing profit margins and improving resource allocation during slower times.
#
# 4. **Diversify Product Offerings**: While it’s beneficial to focus on dominant product categories, exploring emerging sectors or less competitive markets can uncover new growth opportunities. By analyzing underperforming or niche categories with potential, businesses can expand their market share and reduce dependency on a few high-performing areas.
#
# 5. **Adopt Technology-Driven Solutions**: Implementing data analytics, artificial intelligence, and automation can transform decision-making processes. Businesses that leverage these technologies can optimize pricing strategies, manage inventory more effectively, and anticipate demand fluctuations, resulting in lower operational costs and increased adaptability to market changes.
